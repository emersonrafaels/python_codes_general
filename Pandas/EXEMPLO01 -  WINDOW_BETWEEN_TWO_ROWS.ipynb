# %%
import datetime
import operator

# %%
import pandas as pd

# %%
df = pd.read_csv(r'DATA\stockerbot-export.csv', error_bad_lines=False)
# Out:
# b'Skipping line 731: expected 8 fields, saw 13\nSkipping line 2836: expected 8 fields, saw 15\nSkipping line 3058: expected 8 fields, saw 12\nSkipping line 3113: expected 8 fields, saw 12\nSkipping line 3194: expected 8 fields, saw 17\nSkipping line 3205: expected 8 fields, saw 17\nSkipping line 3255: expected 8 fields, saw 17\nSkipping line 3520: expected 8 fields, saw 17\nSkipping line 4078: expected 8 fields, saw 17\nSkipping line 4087: expected 8 fields, saw 17\nSkipping line 4088: expected 8 fields, saw 17\nSkipping line 4499: expected 8 fields, saw 12\n'

# %%
df = df[["timestamp", "company_names"]]

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"])

# %%
df_filter = df[df["company_names"] == "Twenty-First Century Fox"]

# %%
(df_filter.iloc[1]["timestamp"] - df_filter.iloc[0]["timestamp"]) > datetime.timedelta(minutes=2)
# Out:
# True

# %%
def mark_by_duration(dataframe, column_category, 
                     column_time, timedelta_condition, 
                     name_new_column, condition_duration_greater_than=False):
    
    # INICIANDO O SINAL DE CONDIÇÃO
    if condition_duration_greater_than:
        operator_function = operator.gt
    else:
        operator_function = operator.le

    # INICIANDO O DATAFRAME RESULTANTE
    df_result = pd.DataFrame()

    # CRIANDO COLUNA DE COUNT 2MIN
    dataframe[name_new_column] = "-"

    # ORDENANDO POR CATEGORIA E DATAHORA
    dataframe = dataframe.sort_values(by=[column_category, column_time], ascending=True)

    # PERCORRENDO TODAS AS CATEGORIA
    for company in dataframe[column_category].unique():

        # FILTRANDO A CATEGORIA
        df_filter_category = dataframe[dataframe[column_category] == company]
        df_filter_category = df_filter_category.reset_index()

        # PERCORRENDO TODAS AS LINHAS DO DATAFRAME ATUAL
        for idx, row in df_filter_category.iterrows():

            if idx > 0:

                # REALIZANDO OS CALCULOS
                if operator_function((row[column_time] - last_value), datetime.timedelta(minutes=2)):

                    df_filter_category.at[idx, name_new_column] = 1

            # ARMAZENANDO O VALOR DA LINHA ATUAL
            last_value = row[column_time]

        # ARMAZENANDO TODOS OS RESULTADOS PARA A EMPRESA
        df_result = df_result.append(df_filter_category)

    # SALVANDO O RESULTADO FINAL
    df_result = df_result.reset_index()
    
    return df_result

# %%
df_result = mark_by_duration(dataframe=df, column_category="company_names",  
                             column_time="timestamp", timedelta_condition=datetime.timedelta(minutes=2), 
                             name_new_column="COUNT_2", condition_duration_greater_than=False)

# %%
df_result[df_result["company_names"] == "salesforce.com"]
# Out:
#        level_0  index                 timestamp   company_names COUNT_2
# 28209        0  14437 2018-07-17 15:16:05+00:00  salesforce.com       -
# 28210        1  14440 2018-07-17 15:16:31+00:00  salesforce.com       1
# 28211        2  14467 2018-07-17 15:20:58+00:00  salesforce.com       -
# 28212        3  14492 2018-07-17 15:27:10+00:00  salesforce.com       -
# 28213        4  14503 2018-07-17 15:29:22+00:00  salesforce.com       -
# 28214        5  14541 2018-07-17 15:39:54+00:00  salesforce.com       -
# 28215        6  14599 2018-07-17 15:49:27+00:00  salesforce.com       -
# 28216        7  14644 2018-07-17 16:00:49+00:00  salesforce.com       -
# 28217        8  14752 2018-07-17 16:22:35+00:00  salesforce.com       -
# 28218        9  14864 2018-07-17 16:45:45+00:00  salesforce.com       -
# 28219       10  14912 2018-07-17 16:56:54+00:00  salesforce.com       -
# 28220       11  14915 2018-07-17 16:57:10+00:00  salesforce.com       1
# 28221       12  15006 2018-07-17 17:15:33+00:00  salesforce.com       -
# 28222       13  15074 2018-07-17 17:27:01+00:00  salesforce.com       -
# 28223       14  15147 2018-07-17 17:41:32+00:00  salesforce.com       -
# 28224       15  15148 2018-07-17 17:41:33+00:00  salesforce.com       1
# 28225       16  15195 2018-07-17 17:55:11+00:00  salesforce.com       -
# 28226       17  15198 2018-07-17 17:55:34+00:00  salesforce.com       1
# 28227       18  15217 2018-07-17 17:57:51+00:00  salesforce.com       -
# 28228       19  15267 2018-07-17 18:10:37+00:00  salesforce.com       -
# 28229       20  15393 2018-07-17 18:39:35+00:00  salesforce.com       -
# 28230       21  15395 2018-07-17 18:39:54+00:00  salesforce.com       1
# 28231       22  15654 2018-07-17 19:31:14+00:00  salesforce.com       -
# 28232       23  16155 2018-07-17 20:54:57+00:00  salesforce.com       -
# 28233       24  16156 2018-07-17 20:55:07+00:00  salesforce.com       1
# 28234       25  16868 2018-07-17 23:28:34+00:00  salesforce.com       -
# 28235       26  16917 2018-07-17 23:42:25+00:00  salesforce.com       -
# 28236       27  17360 2018-07-18 01:55:05+00:00  salesforce.com       -
# 28237       28  18619 2018-07-18 08:21:11+00:00  salesforce.com       -
# 28238       29  18735 2018-07-18 08:59:58+00:00  salesforce.com       -
# 28239       30  19117 2018-07-18 10:30:37+00:00  salesforce.com       -
# 28240       31  19635 2018-07-18 11:40:06+00:00  salesforce.com       -
# 28241       32  20381 2018-07-18 13:06:15+00:00  salesforce.com       -
# 28242       33  20391 2018-07-18 13:07:00+00:00  salesforce.com       1
# 28243       34  20396 2018-07-18 13:07:30+00:00  salesforce.com       1
# 28244       35  20406 2018-07-18 13:08:07+00:00  salesforce.com       1
# 28245       36  20409 2018-07-18 13:08:29+00:00  salesforce.com       1
# 28246       37  20969 2018-07-18 13:48:28+00:00  salesforce.com       -
# 28247       38  21555 2018-07-18 14:41:03+00:00  salesforce.com       -
# 28248       39  22007 2018-07-18 15:19:35+00:00  salesforce.com       -
# 28249       40  22038 2018-07-18 15:22:32+00:00  salesforce.com       -
# 28250       41  22495 2018-07-18 16:00:38+00:00  salesforce.com       -
# 28251       42  22585 2018-07-18 16:07:56+00:00  salesforce.com       -
# 28252       43  23279 2018-07-18 17:06:27+00:00  salesforce.com       -
# 28253       44  23308 2018-07-18 17:09:01+00:00  salesforce.com       -
# 28254       45  23396 2018-07-18 17:17:17+00:00  salesforce.com       -
# 28255       46  23442 2018-07-18 17:21:03+00:00  salesforce.com       -
# 28256       47  23524 2018-07-18 17:27:11+00:00  salesforce.com       -
# 28257       48  23796 2018-07-18 17:55:21+00:00  salesforce.com       -
# 28258       49  24190 2018-07-18 18:30:05+00:00  salesforce.com       -
# 28259       50  24702 2018-07-18 19:15:02+00:00  salesforce.com       -
# 28260       51  26004 2018-07-18 20:52:12+00:00  salesforce.com       -
# 28261       52  26047 2018-07-18 20:55:09+00:00  salesforce.com       -
# 28262       53  28078 2018-07-18 23:36:24+00:00  salesforce.com       -
